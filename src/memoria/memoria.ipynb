# %% [markdown]
# # Memoria de trabajo

# %% [markdown]
# Siguiendo las recomendaciones del profesorado del bootcamp, inicié mi trabajo de Exploratory Data Analysis con la búsqueda de una base de datos relativa a cuestiones que dominara o bien, conociera. En ese sentido, comencé la búsqueda de datos de psicología y sexología, campos en lo que actualmente trabajo desde la atención sanitaria. En una primera exploración en [www.kaggle.com](https://www.kaggle.com/) localicé un dataset que recogía más de 17000 respuestas a un cuestionario, un instrumento de evaluación sexológica: [Multidimensional Sexual Self Concept Questionnaire](https://www.kaggle.com/datasets/lucasgreenwell/multidimensional-sexual-self-concept-questionnaire).

# %% [markdown]
# ## Multidimensional Sexual Self Concept Questionnaire (MSSCQ)

# %% [markdown]
# El **autoconcepto sexual** comprende la combinación de comportamientos, actitudes y sentimientos seuales, así como las creencias sobre la propia sexualidad de la persona.
#
# El **Cuestionario Multidimensional de Autoconcepto Sexual** (MSSCQ; Snell, 1995) es un instrumento objetivo de autoinforme diseñado para medir, a través de 100 items con 5 opciones de respuesta, los siguientes 20 aspectos psicológicos de la sexualidad humana:
#
# 1. **ANSIEDAD SEXUAL**: definida como la tendencia a sentir tensión, incomodidad y ansiedad acerca de los aspectos sexuales de la propia vida.
#
# Compuesta por los items 1‚ 21‚ 41‚ 61‚ 81.
#
#    - Q1. I feel anxious when I think about the sexual aspects of my life. / Me siento ansioso cuando pienso en los aspectos sexuales de mi vida.
#    - Q21. I worry about the sexual aspects of my life. / Me preocupan los aspectos sexuales de mi vida.
#    - Q41. Thinking about the sexual aspects of my life often leaves me with an uneasy feeling. / Pensar en los aspectos sexuales de mi vida me produce a menudo una sensación de inquietud.
#    - Q61. I worry about the sexual aspects of my life. / Me preocupan los aspectos sexuales de mi vida.
#    - Q81. I feel nervous when I think abut the sexual aspects of my life. / Me siento nervioso cuando pienso en los aspectos sexuales de mi vida.
#
#
# <br>
#
# 2. **AUTOEFICACIA SEXUAL**: definida como la creencia de que uno tiene la capacidad de manejar eficazmente los aspectos sexuales de uno mismo.
#
# Compuesta por los items 2‚ 22‚ 42‚ 62‚ 82
#
#    - Q2. I have the ability to take care of any sexual needs and desires that I may have. / Tengo la capacidad de atender las necesidades y deseos sexuales que pueda tener
#    - Q22. I am competent enough to make sure that my sexual needs are fulfilled. /  Soy lo suficientemente competente como para asegurarme de que se satisfacen mis necesidades sexuales.
#    - Q42. I have the skills and ability to ensure rewarding sexual behaviors for myself. /  Tengo las habilidades y la capacidad para asegurarme comportamientos sexuales gratificantes para mí.
#    - Q62. I am able to cope with and to handle my own sexual needs and wants. / Soy capaz de afrontar y manejar mis propias necesidades y deseos sexuales.
#    - Q82. I have the capability to take care of my own sexual needs and desires. / Tengo capacidad para ocuparme de mis propias necesidades y deseos sexuales.
#
# <br>
#
#
# 3. **CONCIENCIA SEXUAL**: definida como la tendencia a pensar y reflexionar acerca de la naturaleza de la propia sexualidad.
#
# Compuesta por los items 3‚ 23‚ 43‚ 63‚ 83
#
#    - Q3. I am very aware of my sexual feelings and needs. / Soy muy consciente de mis sentimientos y necesidades sexuales.
#    - Q23. I am very aware of my sexual motivations and desires. / Soy muy consciente de mis motivaciones y deseos sexuales.
#    - Q43. I tend to think about my own sexual beliefs and attitudes. / Suelo pensar en mis propias creencias y actitudes sexuales.
#    - Q63. I’m very alert to changes in my sexual thoughts, feelings, and desires. / Estoy muy alerta a los cambios en mis pensamientos, sentimientos y deseos sexuales.
#    - Q83. I am very aware of the sexual aspects of myself (e.g. habits, thoughts, beliefs). /  Soy muy consciente de los aspectos sexuales de mí mismo (por ejemplo, hábitos, pensamientos, creencias).
#
# <br>
#
#
# 4. **MOTIVACIÓN PARA EVITAR EL SEXO DE RIESGO**: definida como la motivación y el deseo de evitar patrones poco saludables de conductas sexuales de riesgo.
#
# Contiene los items 4‚ 24‚ 44‚ 64‚ 84
#
#    - Q4. I am motivated to avoid engaging in "risky" (i.e., unprotected) sexual behavior. / Estoy motivado para evitar comportamientos sexuales "de riesgo" (es decir, sin protección).
#    - Q24. I am motivated to keep myself from having any "risky" sexual behavior (e.g., exposure to sexual diseases). / Estoy motivado para evitar tener cualquier comportamiento sexual "de riesgo" (por ejemplo, exponerme a enfermedades sexuales).
#    - Q44. I want to avoid engaging in sex where I might be exposed to sexual diseases. / Quiero evitar tener relaciones sexuales en las que pueda estar expuesto a enfermedades sexuales.
#    - Q64. I really want to prevent myself from being exposed to sexual diseases. /  Realmente quiero evitar exponerme a enfermedades sexuales.
#    - Q84. I am really motivated to avoid any sexual activity that might expose me to sexual diseases. / Estoy realmente motivado para evitar cualquier actividad sexual que pueda exponerme a enfermedades sexuales.
#
# <br>
#
# 5. **CONTROL SEXUAL POR AZAR/SUERTE**: definido como la creencia de que los aspectos sexuales de la propia vida están determinados por consideraciones de azar y suerte.
#
# Contiene los items 5‚ 25‚ 45‚ 65‚ 85
#
#    - Q5. The sexual aspects of my life are determined mostly by chance happenings. /  Los aspectos sexuales de mi vida están determinados sobre todo por casualidades.
#    - Q25. Most things that affect the sexual aspects of my life happen to me by accident. / La mayoría de las cosas que afectan a los aspectos sexuales de mi vida me ocurren por accidente.
#    - Q45. Luck plays a big part in influencing the sexual aspects of my life./ La suerte influye mucho en los aspectos sexuales de mi vida.
#    - Q65. The sexual aspects of my life are largely a matter of (good or bad) fortune. / Los aspectos sexuales de mi vida dependen en gran medida de la (buena o mala) fortuna.
#    - Q85. The sexual aspects of my life are a matter of fate (destiny). / Los aspectos sexuales de mi vida dependen del destino.
#
#
# <br>
#
# 6. **PREOCUPACIÓN SEXUAL**: definida como la tendencia a pensar en el sexo en un grado excesivo.
#
# Contiene los items 6‚ 26‚ 46‚ 66‚ 86
#
#    - Q6. I think about sex "all the time." / Pienso en sexo "todo el tiempo".
#    - Q26. I think about sex more than anything else. / Pienso en sexo más que en cualquier otra cosa.
#    - Q46. I tend to be preoccupied with sex. / Suelo estar preocupado por el sexo.
#    - Q66. I’m constantly thinking about having sex. / Pienso constantemente en tener relaciones sexuales.
#    - Q86. I think about sex the majority of the time. / Pienso en sexo la mayor parte del tiempo.
#
# <br>
#
#
# 7. **ASERTIVIDAD SEXUAL**: definida como la tendencia a ser asertivo sobre los aspectos sexuales de la propia vida.
#
# Contiene los items 7‚ 27R‚ 47R‚ 67‚ 87. Los items 27 y 47 están invertidos.
#
#    - Q7. I’m very assertive about the sexual aspects of my life. / Soy muy asertivo en los aspectos sexuales de mi vida.
#    - Q27R. I’m not very direct about voicing my sexual needs and preferences. /  No soy muy directo a la hora de expresar mis necesidades y preferencias sexuales.
#    - Q47R. I am somewhat passive about expressing my own sexual desires. / Soy algo pasivo a la hora de expresar mis deseos sexuales.
#    - Q67. I do not hesitate to ask for what I want in a sexual relationship. / No dudo en pedir lo que quiero en una relación sexual.
#    - Q87. When it comes to sex, I usually ask for what I want. / Cuando se trata de sexo, suelo pedir lo que quiero.
#
# <br>
#
# 8. **OPTIMISMO SEXUAL**: definido como la expectativa de que los aspectos sexuales de la propia vida serán positivos y gratificantes en el futuro.
#
# Contiene los items 8‚ 28‚ 48‚ 68R‚ 88R. Los items 68 y 88 están invertidos.
#
#    - Q8. I expect that the sexual aspects of my life will be positive and rewarding in the future. / Espero que los aspectos sexuales de mi vida sean positivos y gratificantes en el futuro.
#    - Q28. I believe that in the future the sexual aspects of my life will be healthy and positive. / Creo que en el futuro los aspectos sexuales de mi vida serán saludables y positivos.
#    - Q48. I do not expect to suffer any sexual problems or frustrations in the future. / No espero tener problemas o frustraciones sexuales en el futuro.
#    - Q68. I will probably experience some sexual problems in the future. / Probablemente experimentaré algunos problemas sexuales en el futuro.
#    - Q88. I anticipate that in the future the sexual aspects of my life will be frustrating. / Preveo que en el futuro los aspectos sexuales de mi vida serán frustrantes.
#
# <br>
#
#
# 9. **AUTOINCULPACIÓN POR PROBLEMAS SEXUALES**: definida como la tendencia a culparse a uno mismo cuando los aspectos sexuales de la propia vida son poco saludables, negativos o indeseables por naturaleza.
#
# Contiene los items 9‚ 29‚ 49‚ 69‚ 89
#
#    - Q9. I would be to blame, if the sexual aspects of my life were not going very well. / Yo tendría la culpa si los aspectos sexuales de mi vida no fueran muy bien.
#    - Q29. If the sexual aspects of my life were to go wrong, I would be the person to blame. / Si los aspectos sexuales de mi vida fueran mal, yo sería la persona culpable.
#    - Q49. If I were to develop a sexual disorder, then I would be to blame for not taking good care of myself. / Si desarrollara un trastorno sexual, la culpa sería mía por no cuidarme bien.
#    - Q69. If I were to develop a sexual problem, then it would be my own fault for letting it happen. / Si tuviera un problema sexual, la culpa sería mía por dejar que ocurriera.
#    - Q89. If something went wrong with my own sexuality, then it would be my own fault. / Si algo saliera mal en mi sexualidad, la culpa sería mía.
#
# <br>
#
#
# 10. **SUPERVISIÓN SEXUAL**: definida como la tendencia a ser consciente de la impresión pública que la propia sexualidad causa en los demás.
#
# Contiene los items 10‚ 30‚ 50‚ 70‚ 90
#
#    - Q10. I notice how others perceive and react to the sexual aspects of my life. / Me doy cuenta de cómo los demás perciben y reaccionan ante los aspectos sexuales de mi vida.
#    - Q30. I’m concerned with how others evaluate my own sexual beliefs and behaviors. / Me preocupa cómo evalúan los demás mis propias creencias y comportamientos sexuales.
#    - Q50. I am quick to notice other people’s reactions to the sexual aspects of my own life. / Me fijo rápidamente en las reacciones de los demás ante los aspectos sexuales de mi propia vida.
#    - Q70. I’m concerned about how the sexual aspects of my life appear to others. / Me preocupa cómo los demás perciben los aspectos sexuales de mi vida.
#    - Q90. I’m aware of the public impression created by my own sexual behaviors and attitudes. / Soy consciente de la impresión pública que crean mis propios comportamientos y actitudes sexuales.
#
#
# <br>
#
# 11. **MOTIVACIÓN SEXUAL**:  definida como la motivación y el deseo de involucrarse en una relación sexual.
#
# Contiene los items 11‚ 31‚ 51‚ 71‚ 91
#
#    - Q11. I’m motivated to be sexually active. / Estoy motivado para ser sexualmente activo.
#    - Q31. I’m motivated to devote time and effort to sex. / Estoy motivado para dedicar tiempo y esfuerzo a las relaciones sexuales.
#    - Q51. I have a desire to be sexually active. / Tengo el deseo de ser sexualmente activo.
#    - Q71. It’s important to me that I involve myself in sexual activity. / Para mí es importante participar en actividades sexuales.
#    - Q91. I strive to keep myself sexually active. / Me esfuerzo por mantenerme sexualmente activo.
#
# <br>
#
#
# 12. **GESTIÓN DE PROBLEMAS SEXUALES**: definida como la tendencia a creer que uno tiene la capacidad/habilidades para gestionar y manejar eficazmente cualquier problema sexual que uno pueda desarrollar o encontrar.
#
# Contiene los items 12‚ 32‚ 52‚ 72‚ 92
#
#    - Q12. If I were to experience a sexual problem, I myself would in control of whether this improved. / Si tuviera un problema sexual, yo mismo controlaría si mejorara.
#    - Q32. If I were to experiences a sexual problem, my own behavior would determine whether I improved. / Si experimentara un problema sexual, mi propio comportamiento determinaría si mejorara.
#    - Q52. If I were to become sexually maladjusted, I myself would be responsible for making myself better. /  Si experimentara una inadaptación sexual, yo mismo sería responsable de que mejorara.
#    - Q72. If I developed any sexual problems, my recovery would depend in large part on what I myself would do. / Si desarrollara algún problema sexual, mi recuperación dependería en gran parte de lo que yo mismo hiciera.
#    - Q92. If I developed a sexual disorder, my recovery would depend on how I myself dealt with the problem. / Si desarrollara algún trastorno sexual, mi recuperación dependería de cómo yo mismo afrontara el problema.
#
# <br>
#
#
# 13. **AUTOESTIMA SEXUAL**: definida como la tendencia generalizada a evaluar positivamente la propia capacidad para participar en conductas sexuales saludables y experimentar la propia sexualidad de forma satisfactoria y placentera.
#
# Contiene los items 13‚ 33‚ 53‚ 73‚ 93
#
#    - Q13. I derive a sense of self-pride from the way I handle my own sexual needs and desires. / Me siento orgulloso de la forma en que manejo mis necesidades y deseos sexuales.
#    - Q33. I am proud of the way I deal with and handle my own sexual desires and needs. / Me siento orgulloso de la forma en que afronto y manejo mis deseos y necesidades sexuales.
#    - Q53. I am pleased with how I handle my own sexual tendencies and behaviors. / Estoy satisfecho/a de cómo manejo mis tendencias y comportamientos sexuales.
#    - Q73. I have positive feelings about the way I approach my own sexual needs and desires. / Tengo sentimientos positivos sobre la forma en que afronto mis necesidades y deseos sexuales.
#    - Q93. I feel good about the way I express my own sexual needs and desires. / Me siento bien con la forma en que expreso mis necesidades y deseos sexuales.
#
#
# <br>
#
#
# 14. **SATISFACCIÓN SEXUAL**: definida como la tendencia a estar muy satisfecho con los aspectos sexuales de la propia vida.
#
# Contiene los items 14‚ 34‚ 54‚ 74‚ 94
#
#    - Q14. I am satisfied with the way my sexual needs are currently being met. / Estoy satisfecho/a con la forma en que se satisfacen actualmente mis necesidades sexuales.
#    - Q34. I am satisfied with the status of my own sexual fulfillment. /  Estoy satisfecho/a con el estado de mi propia realización sexual.
#    - Q54. The sexual aspects of my life are personally gratifying to me. / Los aspectos sexuales de mi vida me resultan personalmente gratificantes.
#    - Q74. The sexual aspects of my life are satisfactory, compared to most people’s. /  Los aspectos sexuales de mi vida son satisfactorios, comparados con los de la mayoría de la gente.
#    - Q94. I am satisfied with the sexual aspects of my life. / Estoy satisfecho con los aspectos sexuales de mi vida.
#
#
# <br>
#
#
#
# 15. **CONTROL SEXUAL POR PARTE DE OTROS**: definida como la creencia de que los aspectos sexuales de la propia vida están controlados por otros más poderosos e influyentes que uno mismo.
#
# Contiene los items 15‚ 35‚ 55‚ 75‚ 95
#
#    - Q15. My sexual behaviors are determined largely by other more powerful and influential people. / Mis comportamientos sexuales están determinados en gran medida por otras personas más poderosas e influyentes.
#    - Q35. My sexual behaviors are largely controlled by people other than myself (e.g., my partner, friends, family). / Mis comportamientos sexuales están controlados en gran medida por otras personas (por ejemplo, mi pareja, mis amigos, mi familia).
#    - Q55. My sexual behavior is determined by the actions of powerful others (e.g., my partner, friends, family). /  Mi comportamiento sexual está determinado por las acciones de otras personas poderosas (por ejemplo, mi pareja, amigos, familia).
#    - Q75. In order to be sexually active, I have to conform to other more powerful individuals. / Para ser sexualmente activo, tengo que conformarme con otros individuos más poderosos.
#    - Q95. My sexual behavior is mostly determined by people who have influence and control over me. /  Mi comportamiento sexual está determinado principalmente por personas que tienen influencia y control sobre mí.
#
#
# <br>
#
#
# 16. **AUTOESQUEMAS SEXUALES**: definidos como un marco cognitivo que organiza y guía el procesamiento de la información sobre los aspectos de uno mismo relacionados con la sexualidad.
#
# Contiene los items 16‚ 36‚ 56‚ 76‚ 96
#
#    - Q16. Not only would I be a good sexual partner, but it’s quite important to me that I be a good sexual partner. / No sólo sería una buena pareja sexual, sino que para mí es bastante importante que lo sea.
#    - Q36. Not only would I be a skilled sexual partner, but it’s very important to me that I be a skilled sexual partner. / No sólo sería una hábil pareja sexual, sino que es muy importante para mí que sea una hábil pareja sexual.
#    - Q56. Not only could I relate well to a sexual partner, but it’s important to me that I be able to do so. /  No sólo podría relacionarme bien con una pareja sexual, sino que es importante para mí poder hacerlo.
#    - Q76. I am able to "connect" well with a sexual partner, and it’s important to me that I am able to do so. /  Soy capaz de "conectar" bien con una pareja sexual, y es importante para mí que sea capaz de hacerlo.
#    - Q96. Not only am I be capable of relating to a sexual partner, but it’s important to me that I relate very well. / No sólo soy capaz de relacionarme con una pareja sexual, sino que es importante para mí que me relacione muy bien.
#
# <br>
#
#
# 17. **MIEDO AL SEXO**: definido como el miedo a mantener relaciones sexuales con otra persona.
#
# Contiene los items 17‚ 37‚ 57‚ 77R‚ 97R. Los items 77 y 97 están invertidos.
#
#    - Q17. I am afraid of becoming sexual involved with another person. / Tengo miedo de involucrarme sexualmente con otra persona.
#    - Q37. I have a fear of sexual relationships. / Tengo miedo a las relaciones sexuales.
#    - Q57. I am fearful of engaging sexual activity. / Tengo miedo a mantener relaciones sexuales.
#    - Q77. I don’t have much fear about engaging in sex. / No tengo mucho miedo a mantener relaciones sexuales
#    - Q97. I’m not afraid of becoming sexually active. / No tengo miedo a mantener relaciones sexuales.
#
#
# <br>
#
#
# 18. **PREVENCIÓN DE PROBLEMAS SEXUALES**: definida como la creencia de que uno tiene la capacidad de evitar desarrollar problemas o trastornos sexuales.
#
# Contiene los items 18‚ 38‚ 58‚ 78‚ 98
#
#    - Q18. If I am careful, then I will be able to prevent myself from having any sexual problems. / Si tengo cuidado, podré evitar tener problemas sexuales.
#    - Q38. I can pretty much prevent myself from developing sexual problems by taking good care of myself. /  Puedo evitar en gran medida tener problemas sexuales si me cuido bien.
#    - Q58. If just I look out for myself, then I will be able to avoid any sexual problems in the future. / Si me cuido, podré evitar cualquier problema sexual en el futuro.
#    - Q78. I will be able to avoid any sexual problems, if I just take good care of myself. / Podré evitar cualquier problema sexual si me cuido bien.
#    - Q98. If I just pay careful attention, I’ll be able to prevent myself from having any sexual problems. / Si me cuido, podré evitar cualquier problema sexual.
#
#
# <br>
#
#
# 19. **DEPRESIÓN SEXUAL**: definida como la experiencia de sentimientos de tristeza, infelicidad y depresión en relación con la propia vida sexual.
#
# Contiene los items 19‚ 39‚ 59‚ 79‚ 99
#
#    - Q19. I am depressed about the sexual aspects of my life. / Me deprimen los aspectos sexuales de mi vida.
#    - Q39. I am disappointed about the quality of my sex life. /  Me decepciona la calidad de mi vida sexual.
#    - Q59. I feel discouraged about my sex life. / Mi vida sexual me desanima.
#    - Q79. I feel unhappy about my sexual experiences. / No estoy satisfecho/a con mis experiencias sexuales.
#    - Q99. I feel sad when I think about my sexual experiences. / Me siento triste cuando pienso en mis experiencias sexuales.
#
# <br>
#
#
# 20. **CONTROL SEXUAL INTERNO**: definido como la creencia de que los aspectos sexuales de la propia vida están determinados por el propio control personal.
#
# Contiene los items 20‚ 40‚ 60‚ 80‚ 100
#
#    - Q20. My sexuality is something that I am largely responsible for. / Mi sexualidad es algo de lo que soy responsable en gran medida.
#    - Q40. The sexual aspects of my life are determined in large part by my own behavior. / Los aspectos sexuales de mi vida están determinados en gran parte por mi propio comportamiento.
#    - Q60. I am in control of and am responsible for the sexual aspects of my life. / Controlo y soy responsable de los aspectos sexuales de mi vida.
#    - Q80. The main thing which affects the sexual aspects of my life is what I myself do. / Lo que más influye en los aspectos sexuales de mi vida es lo que yo mismo hago.
#    - Q100. My sexuality is something that I myself am in charge of. / Mi sexualidad es algo de lo que yo mismo soy responsable.

# %% [markdown]
# ## Planteamiento de hipótesis

# %% [markdown]
# HIPÓTESIS PRINCIPAL:
#
# [El género y la edad tienen relación con el autoconcepto sexual que pueda tener una persona.](#Hipótesis-principal:-El género-y-la-edad-tienen-relación-con-el-autoconcepto-sexual-que-pueda-tener-una-persona.)
#
# OTRAS HIPÓTESIS:
#
# - H1. Habrá diferencias significativas entre hombres y mujeres en cuanto a la vivencia de la ansiedad sexual.
# - H2. La ansiedad sexual se vivirá en mayor o menor intensidad según el grupo de edad al que pertenezca una persona.
# - H3. La satisfación sexual se vivirá de forma diferente según el grupo de edad al que pertenezca la persona
# - H4. La satisfacción sexual correlacionará de forma positiva con la autoestima sexual.
# - H5. La ansiedad sexual correlacionará positivamente con la supervisión sexual.

# %% [markdown]
# ## Primera exploración

# %% [markdown]
# Importo librerías necesarias para el EDA, hago una primera exploración de filas y columnas del dataset, tipo de datos y descripción de los mismos.

# %% [markdown]
# ### Librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv("../data/data.csv", delimiter = "\t") #Especificar delimitador de columnas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17685 entries, 0 to 17684
# Columns: 102 entries, Q1 to gender
# dtypes: int64(102)
# memory usage: 13.8 MB

# %%
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q93  Q94  Q95  Q96  Q97  Q98  \
# 0   3   2   5   5   1   2   2   1   1    2  ...    4    1    1    5    5    3
# 1   5   1   5   1   1   2   1   3   1    1  ...    1    1    1    2    1    1
# 2   1   4   5   5   1   4   5   5   5    4  ...    5    5    1    5    4    4
# 3   5   4   5   5   5   5   2   4   5    5  ...    4    1    2    5    0    4
# 4   4   5   4   5   4   2   3   2   4    5  ...    1    1    3    1    1    1
#
#    Q99  Q100  age  gender
# 0    5     4   23       1
# 1    5     3   25       2
# 2    1     4   20       1
# 3    5     5   23       2
# 4    4     3   50       2
#
# [5 rows x 102 columns]

# %% [markdown]
# Se observan los 100 items del MSSCQ, la edad y el género, un total de 102 columnas.

# %%
nulls = df.isnull().sum().all()
nulls
# Out:
# False

# %% [markdown]
# No hay valores nulos en la base de datos.

# %%
df["gender"].value_counts()
# Out:
# gender
# 2    9944
# 1    7298
# 3     378
# 0      65
# Name: count, dtype: int64

# %% [markdown]
# Las opciones de respuesta del cuestionario son 5, siendo: 1=Not at all characteristic of me, 2=Slightly characteristic of me, 3=Somewhat characteristic of me, 4=Moderately characteristic of me, 5=Very characteristic of me. Hago un describe para ver si los mínimos y máximos de respuesta coinciden. Si no es así, limpio.

# %%
df.describe()
# Out:
#                  Q1            Q2            Q3            Q4            Q5  \
# count  17685.000000  17685.000000  17685.000000  17685.000000  17685.000000
# mean       2.608538      3.450721      4.032061      3.414589      2.526944
# std        1.403072      1.340230      1.182624      1.517489      1.411380
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      2.000000      3.000000      2.000000      1.000000
# 50%        2.000000      4.000000      4.000000      4.000000      2.000000
# 75%        4.000000      5.000000      5.000000      5.000000      4.000000
# max        5.000000      5.000000      5.000000      5.000000      5.000000
#
#                  Q6            Q7            Q8            Q9           Q10  \
# count  17685.000000  17685.000000  17685.000000  17685.000000  17685.000000
# mean       2.943964      2.811479      3.496579      3.343116      3.129262
# ...

# %% [markdown]
# Tengo un dataset con 17685 filas (personas que han respondido al cuestionario) y 102 columnas, relativas a los 100 items del cuestionario, edad y género. Todas las variables son int (variables numéricas).

# %% [markdown]
# Observo que el mínimo en las respuesta de los items Q1 a Q100 es de 0, lo cual no tiene sentido, no es un valor válido para el cuestionario. Elimino las filas de las columnas cuya respuesta a algún ítem sea 0, ya que no da fiabilidad en la respuesta de la persona.

# %%
df = df.drop(df[(df.iloc[:, :100] == 0).any(axis=1)].index)

# %%
df.describe()
# Out:
#                  Q1            Q2            Q3            Q4            Q5  \
# count  12789.000000  12789.000000  12789.000000  12789.000000  12789.000000
# mean       2.617953      3.460787      4.056768      3.441708      2.530456
# std        1.391395      1.317384      1.133655      1.492600      1.400305
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      2.000000      4.000000      2.000000      1.000000
# 50%        2.000000      4.000000      4.000000      4.000000      2.000000
# 75%        4.000000      5.000000      5.000000      5.000000      4.000000
# max        5.000000      5.000000      5.000000      5.000000      5.000000
#
#                  Q6            Q7            Q8            Q9           Q10  \
# count  12789.000000  12789.000000  12789.000000  12789.000000  12789.000000
# mean       2.952694      2.823598      3.518962      3.379701      3.160138
# ...

# %% [markdown]
# Según el codebook, la codificación de la base de dato en cuanto al género refiere que 1 = "hombre" ; 2 = "mujer" ; 3 = "otro" ; 0 = "no eligió". Dados los pocos valores de 0 y 3, eliminaremos esas filas en el apartado de Limpieza y sólo dejamos en la base de datos las respuestas de hombres y mujeres.

# %% [markdown]
# En cuanto a la edad, se observa que el mínimo es de 13 años y el máximo no es real, puesto que es una persona con más de 8 millones de años. En el apartado de Limpieza se procederá a crear grupos de edades relativos a la adolescencia, juventud, adultez y vejez, previamente habiendo limpiado las edades dejando un límite máximo de 105 años.

# %%
plt.hist(df["age"], bins=range(13, 100, 1), edgecolor='black')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de edades')
plt.show()

# %% [markdown]
# ## Limpieza

# %% [markdown]
# ### Género

# %% [markdown]
# Haciendo uso del codebook, se eliminan los géneros que han sido codificados con 0 y 3. Se deja un dataset sólo con hombres y mujeres.

# %%
df = df.drop(df[(df["gender"] == 0) | (df["gender"] == 3)].index)

# %%
df["gender"].value_counts()
# Out:
# gender
# 2    7148
# 1    5310
# Name: count, dtype: int64

# %% [markdown]
# Convertimos el género (int) a categórica (str)

# %%
# Mapear los valores numéricos a categorías con la función map de pandas que trabaja con diccionario:
df['gender'] = df['gender'].map({1: 'man', 2: 'woman'})

# %% [markdown]
# ### Edad

# %% [markdown]
# En vista a la presencia de datos irreales e imposibles, hago limpieza y establezco como población objetivo pesonas de un mínimo de edad de 13 y máximo 100 años.

# %%
df = df.drop(df[df["age"] >= 105].index)

# %%
df["age"].describe()
# Out:
# count    12451.000000
# mean        26.319251
# std         10.778887
# min         13.000000
# 25%         19.000000
# 50%         22.000000
# 75%         31.000000
# max         99.000000
# Name: age, dtype: float64

# %%
df.describe()
# Out:
#                  Q1            Q2            Q3            Q4            Q5  \
# count  12451.000000  12451.000000  12451.000000  12451.000000  12451.000000
# mean       2.613043      3.463336      4.061120      3.439965      2.530801
# std        1.390607      1.315035      1.130607      1.491014      1.398994
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      2.000000      4.000000      2.000000      1.000000
# 50%        2.000000      4.000000      4.000000      4.000000      2.000000
# 75%        4.000000      5.000000      5.000000      5.000000      4.000000
# max        5.000000      5.000000      5.000000      5.000000      5.000000
#
#                  Q6            Q7            Q8            Q9           Q10  \
# count  12451.000000  12451.000000  12451.000000  12451.000000  12451.000000
# mean       2.954702      2.825877      3.527909      3.378925      3.155891
# ...

# %% [markdown]
# Ahora tengo una base de datos sólo con hombres y mujeres de edades comprendidas entre los 13 y 99 años.

# %% [markdown]
# Creamos una variable relativa al "Grupo de edad" de las personas de modo que:
# - Adolescencia (de 13 a 19 años)
# - Juventud (de 20 a 30 años)
# - Adultez (de 31 a 64 años)
# - Vejez (de 65 a 99 años)

# %%
# Definir los límites de los grupos de edad
bins = [13, 19, 30, 64, 100]
labels = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

# Crear la columna "Grupo de edad" utilizando pd.cut() que divide la columna "age" en rangos en función de los bins que he declarado antes
df['Age Group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# %%
df["Age Group"].value_counts()
# Out:
# Age Group
# Youth          6113
# Adulthood      3312
# Adolescence    2947
# Elderly          79
# Name: count, dtype: int64

# %% [markdown]
# Quiero ver cómo de repartidas están las edades:

# %%
# Crear un diccionario para almacenar la cantidad de veces que se repite cada edad
cantidad_edades = {}

# Iterar sobre las edades desde 13 hasta 100 años
for edad in range(13, 101):
    # Contar la cantidad de veces que aparece cada edad y guardarla en el diccionario
    cantidad_edades[edad] = (df['age'] == edad).sum()

# Imprimir la cantidad de veces que se repiten las edades
for edad, cantidad in cantidad_edades.items():
    print(f"Edad: {edad}, Repeticiones: {cantidad}")
# Out:
# Edad: 13, Repeticiones: 22
# Edad: 14, Repeticiones: 99
# Edad: 15, Repeticiones: 302
# Edad: 16, Repeticiones: 596
# Edad: 17, Repeticiones: 806
# Edad: 18, Repeticiones: 1122
# Edad: 19, Repeticiones: 980
# Edad: 20, Repeticiones: 881
# Edad: 21, Repeticiones: 776
# Edad: 22, Repeticiones: 659
# Edad: 23, Repeticiones: 611
# Edad: 24, Repeticiones: 498
# Edad: 25, Repeticiones: 469
# Edad: 26, Repeticiones: 356
# Edad: 27, Repeticiones: 326
# Edad: 28, Repeticiones: 317
# Edad: 29, Repeticiones: 240
# Edad: 30, Repeticiones: 267
# Edad: 31, Repeticiones: 198
# Edad: 32, Repeticiones: 216
# Edad: 33, Repeticiones: 206
# Edad: 34, Repeticiones: 177
# Edad: 35, Repeticiones: 194
# Edad: 36, Repeticiones: 131
# Edad: 37, Repeticiones: 128
# Edad: 38, Repeticiones: 133
# Edad: 39, Repeticiones: 111
# Edad: 40, Repeticiones: 141
# Edad: 41, Repeticiones: 94
# Edad: 42, Repeticiones: 105
# Edad: 43, Repeticiones: 89
# Edad: 44, Repeticiones: 117
# Edad: 45, Repeticiones: 119
# ...

# %% [markdown]
# Se crea la columna "years_old" para crear grupos por cada año de edad, es decir, grupo para los 13 años, para los 14... para los 99 años... de modo que permitirá el análisis por edades concretas posteriormente.

# %%
# Definir los límites de los grupos de edad
bins = list(range(13, 102))
labels = [f"{i} years old" for i in range(13, 101)]

# Crear la columna "years_old" utilizando pd.cut()
df['years_old'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# %%
# Establecer el tamaño de la figura y el tamaño de la fuente
plt.figure(figsize=(20, 10))  # Ajusta el tamaño de la figura según sea necesario
plt.xticks(rotation=90, fontsize=10)  # Rotar y ajustar el tamaño de la fuente de las etiquetas del eje x
plt.yticks(fontsize=12)  # Ajustar el tamaño de la fuente de las etiquetas del eje y

# Graficar el histograma de la columna "years_old"
df["years_old"].value_counts().sort_index().plot(kind='bar', width=0.8)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Se observa la distribución por género y por grupos de edad.

# %%
grouped_counts = df.groupby(["Age Group", "gender"]).size()
grouped_counts
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_19220\3219836235.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_counts = df.groupby(["Age Group", "gender"]).size()
# Age Group    gender
# Adolescence  man        990
#              woman     1957
# Youth        man       2492
#              woman     3621
# Adulthood    man       1761
#              woman     1551
# Elderly      man         63
#              woman       16
# dtype: int64

# %%
# Reorganizar los datos para tener una estructura más adecuada para la gráfica
grouped_counts_unstacked = grouped_counts.unstack()

# Graficar los datos
grouped_counts_unstacked.plot(kind='bar', color=["blue", "pink"])

# Añadir etiquetas y título
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Count of men and women by age group')
plt.xticks(rotation=360)  # Rotar las etiquetas del eje x para mejorar la legibilidad

# Mostrar la gráfica
plt.legend(title='Gender')
plt.tight_layout()  # Ajustar el diseño para evitar que se superpongan los elementos
plt.show()

# %% [markdown]
# Se observa muy poca representación del grupo de la vejez.

# %% [markdown]
# ### Categorías

# %% [markdown]
# Se crean las 20 variables que serán objetos de estudio. Para ello, se tiene en cuenta la necesidad de invertir las respuestas de algunos items debido a su enunciado.

# %% [markdown]
# ### Información de las columnas

# %% [markdown]
# - age: edad. (numérica)
# - gender: género (hombre o mujer). (categórica)
# - Age Group: Grupos de edades (adolesencia, juventud, adultez, vejez). (categórica)
# - years_old: Grupo por cada año de edad (13 years old, 14 years old..., 100 years old). (categórica)
# - Sexual_anxiety: ansiedad sexual (numérica)
# - Sexual_self-efficacy: autoeficacia sexual (numérica)
# - Sexual_consciousness: conciencia sexual (numérica)
# - Motivation_to_avoid_risky_sex: motivación para evitar sexo de riesgo (numérica)
# - Chance/luck_sexual_control: control sexual por azar/suerte (numérica)
# - Sexual_preoccupation: preocupación sexual (numérica)
# - Sexual_assertiveness: asertividad sexual (numérica)
# - Sexual_optimism: optimismo sexual (numérica)
# - Sexual_problem_self-blame: autoinculpación
# - Sexual_monitoring: monitoreo sexual (numérica)
# - Sexual_motivation: motivación sexual (numérica)
# - Sexual_problem_management: gestión de problemas sexuales (numérica)
# - Sexual_self-esteem: autoestima sexual (numérica)
# - Sexual_satisfaction: satisfacción sexual (numérica)
# - Power_other_sexual_control: control sexual por parte de otros (numérica)
# - Sexual_self-schemata: autoesquemas sexuales (numérica)
# - Fear_of_sex: miedo al sexo (numérica)
# - Sexual_problem_prevention: prevención de problemas sexales (numérica)
# - Sexual_depression: depresión sexual (numérica)
# - Internal_sexual_control: control sexual interno (numérica)

# %%
#Items que queremos invertir
items_to_invert = ['Q27', 'Q47', 'Q68', 'Q88', 'Q77', 'Q97']

# Invertir los items. Si en un item la respuesta era 1, ahora será 5. Si era 2, ahora será 4...
df[items_to_invert] = df[items_to_invert].apply(lambda x: 6 - x)

# Crear columnas por cada categoría o temática sexual mediante la media de la suma de los items correspondientes
df['Sexual_anxiety'] = df[['Q1', 'Q21', 'Q41', 'Q61', 'Q81']].mean(axis=1)
df['Sexual_self-efficacy'] = df[['Q2', 'Q22', 'Q42', 'Q62', 'Q82']].mean(axis=1)
df['Sexual_consciousness'] = df[['Q3', 'Q23', 'Q43', 'Q63', 'Q83']].mean(axis=1)
df['Motivation_to_avoid_risky_sex'] = df[['Q4', 'Q24', 'Q44', 'Q64', 'Q84']].mean(axis=1)
df['Chance/luck_sexual_control'] = df[['Q5', 'Q25', 'Q45', 'Q65', 'Q85']].mean(axis=1)
df['Sexual_preoccupation'] = df[['Q6', 'Q26', 'Q46', 'Q66', 'Q86']].mean(axis=1)
df['Sexual_assertiveness'] = df[['Q7', 'Q27', 'Q47', 'Q67', 'Q87']].mean(axis=1)
df['Sexual_optimism'] = df[['Q8', 'Q28', 'Q48', 'Q68', 'Q88']].mean(axis=1)
df['Sexual_problem_self-blame'] = df[['Q9', 'Q29', 'Q49', 'Q69', 'Q89']].mean(axis=1)
df['Sexual_monitoring'] = df[['Q10', 'Q30', 'Q50', 'Q70', 'Q90']].mean(axis=1)
df['Sexual_motivation'] = df[['Q11', 'Q31', 'Q51', 'Q71', 'Q91']].mean(axis=1)
df['Sexual_problem_management'] = df[['Q12', 'Q32', 'Q52', 'Q72', 'Q92']].mean(axis=1)
df['Sexual_self-esteem'] = df[['Q13', 'Q33', 'Q53', 'Q73', 'Q93']].mean(axis=1)
df['Sexual_satisfaction'] = df[['Q14', 'Q34', 'Q54', 'Q74', 'Q94']].mean(axis=1)
df['Power_other_sexual_control'] = df[['Q15', 'Q35', 'Q55', 'Q75', 'Q95']].mean(axis=1)
df['Sexual_self-schemata'] = df[['Q16', 'Q36', 'Q56', 'Q76', 'Q96']].mean(axis=1)
df['Fear_of_sex'] = df[['Q17', 'Q37', 'Q57', 'Q77', 'Q97']].mean(axis=1)
df['Sexual_problem_prevention'] = df[['Q18', 'Q38', 'Q58', 'Q78', 'Q98']].mean(axis=1)
df['Sexual_depression'] = df[['Q19', 'Q39', 'Q59', 'Q79', 'Q99']].mean(axis=1)
df['Internal_sexual_control'] = df[['Q20', 'Q40', 'Q60', 'Q80', 'Q100']].mean(axis=1)

# %%
df
# Out:
#        Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Sexual_motivation  \
# 0       3   2   5   5   1   2   2   1   1    2  ...                3.4
# 2       1   4   5   5   1   4   5   5   5    4  ...                4.8
# 5       5   1   2   1   1   1   1   2   5    2  ...                3.2
# 6       5   1   5   3   5   4   3   1   1    1  ...                4.2
# 7       2   4   5   1   1   3   2   4   4    3  ...                5.0
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...                ...
# 17680   1   4   5   5   2   1   1   2   4    3  ...                4.6
# 17681   3   4   2   1   1   1   1   1   1    4  ...                2.0
# 17682   2   4   4   3   2   2   4   5   5    3  ...                4.0
# 17683   1   5   5   5   3   1   5   5   5    5  ...                2.0
# 17684   3   1   2   5   3   3   4   3   4    1  ...                4.6
#
#        Sexual_problem_management  Sexual_self-esteem  Sexual_satisfaction  \
# ...

# %% [markdown]
# Se guarda el nuevo dataframe  **df_q_dimension.csv** que contiene  124 columnas (100 items (Q) del cuestionario, 20 categorías sexuales de evaluación, género (categórica), edad (numérica), años (grupo de año), grupo de edad (categórica)).

# %%
df.to_csv("../data/df_q_dimension.csv", index = False)

# %% [markdown]
# Se abre para observar sus características y trabajar con él.

# %%
df = pd.read_csv("../data/df_q_dimension.csv")

# %%
df
# Out:
#        Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Sexual_motivation  \
# 0       3   2   5   5   1   2   2   1   1    2  ...                3.4
# 1       1   4   5   5   1   4   5   5   5    4  ...                4.8
# 2       5   1   2   1   1   1   1   2   5    2  ...                3.2
# 3       5   1   5   3   5   4   3   1   1    1  ...                4.2
# 4       2   4   5   1   1   3   2   4   4    3  ...                5.0
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...                ...
# 12446   1   4   5   5   2   1   1   2   4    3  ...                4.6
# 12447   3   4   2   1   1   1   1   1   1    4  ...                2.0
# 12448   2   4   4   3   2   2   4   5   5    3  ...                4.0
# 12449   1   5   5   5   3   1   5   5   5    5  ...                2.0
# 12450   3   1   2   5   3   3   4   3   4    1  ...                4.6
#
#        Sexual_problem_management  Sexual_self-esteem  Sexual_satisfaction  \
# ...

# %%
df.describe()
# Out:
#                  Q1            Q2            Q3            Q4            Q5  \
# count  12451.000000  12451.000000  12451.000000  12451.000000  12451.000000
# mean       2.613043      3.463336      4.061120      3.439965      2.530801
# std        1.390607      1.315035      1.130607      1.491014      1.398994
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      2.000000      4.000000      2.000000      1.000000
# 50%        2.000000      4.000000      4.000000      4.000000      2.000000
# 75%        4.000000      5.000000      5.000000      5.000000      4.000000
# max        5.000000      5.000000      5.000000      5.000000      5.000000
#
#                  Q6            Q7            Q8            Q9           Q10  \
# count  12451.000000  12451.000000  12451.000000  12451.000000  12451.000000
# mean       2.954702      2.825877      3.527909      3.378925      3.155891
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12451 entries, 0 to 12450
# Columns: 124 entries, Q1 to Internal_sexual_control
# dtypes: float64(20), int64(101), object(3)
# memory usage: 11.8+ MB

# %% [markdown]
# Se eliminan las 100 columnas relativas a los 100 items del cuestionario para que resulte más cómodo el trabajo de análisis.

# %%
df = df.drop(df.columns[0:100], axis = 1)

# %%
df
# Out:
#        age gender    Age Group     years_old  Sexual_anxiety  \
# 0       23    man        Youth  23 years old             3.8
# 1       20    man        Youth  20 years old             1.4
# 2       51  woman    Adulthood  51 years old             3.2
# 3       51    man    Adulthood  51 years old             5.0
# 4       30    man    Adulthood  30 years old             1.6
# ...    ...    ...          ...           ...             ...
# 12446   24    man        Youth  24 years old             1.6
# 12447   17  woman  Adolescence  17 years old             1.6
# 12448   18  woman  Adolescence  18 years old             2.0
# 12449   19  woman        Youth  19 years old             1.0
# 12450   29  woman        Youth  29 years old             3.6
#
#        Sexual_self-efficacy  Sexual_consciousness  \
# 0                       2.8                   4.2
# 1                       4.6                   4.8
# 2                       1.6                   3.0
# ...

# %% [markdown]
# Se genera y guarda un nuevo dataframe,  **df_only_dimension.csv**, que contiene 24 columnas (20 categorías sexuales, género (categórica), edad (numérica), años (grupo de año), grupo de edad (categórica)). Es el archivo con el que se trabajará el grueso del EDA.

# %%
df.to_csv("../data/df_only_dimension.csv", index = False)

# %% [markdown]
# ## Análisis

# %% [markdown]
# ## Hipótesis principal: El género y la edad tienen relación con el autoconcepto sexual que pueda tener una persona.

# %% [markdown]
# Lo primero de todo, se comprueba el supuesto de normalidad con la prueba Kolmogorov-Smirnov sobre la variable dependiente, en este caso, las categorías sexuales relativas al autoconcepto sexual. Como los resultados de p valor son menores de 0.05, se asume que las distribuciones no son normales por lo que se procederá a hacer pruebas estadísticas no paramétricas.
#
# En el caso de analizar la relación entre género (categórica bivariada) y las categorías sexuales (numéricas), se hará la prueba de Mann-Whitney.
# En el caso de analizar la relación entre los grupos de edad (categórico multivariado) y las categorías sexuales (numéricas), se hará la prueba de Kruskal-Wallis.

# %%
from scipy.stats import kstest
ks_statistic, p_value = kstest(df['Sexual_anxiety'], 'norm')
print(f"Estadístico KS: {ks_statistic}")
print(f"Valor P: {p_value}")
# Out:
# Estadístico KS: 0.8413447460685429
# Valor P: 0.0

# %% [markdown]
# La distribución no es normal, por lo que se llevará a cabo prueba no paramétrica de análisis. En este caso, prueba U Mann-Whitney para analizar la relación entre ansiedad sexual y género.

# %% [markdown]
# ### H1. Habrá diferencias significativas entre hombres y mujeres en cuanto a la vivencia de la ansiedad sexual.

# %% [markdown]
# Se lleva a cabo la prueba U de Mann-Whitney y se observan pequeñas pero significativas diferencias entre hombres y mujeres.

# %%
from scipy.stats import mannwhitneyu

sexual_anxiety_woman = df[df['gender'] == 'woman']['Sexual_anxiety']
sexual_anxiety_man = df[df['gender'] == 'man']['Sexual_anxiety']
u_statistic, p_value = mannwhitneyu(sexual_anxiety_woman, sexual_anxiety_man, alternative='two-sided')
print('U Statistic:', u_statistic)
print('P-Value:', p_value)
# Out:
# U Statistic: 17759577.0
# P-Value: 1.540385163982365e-09

# %% [markdown]
# Parece que sí hay relación significativa entre el género y la ansiedad sexual sufrida, aunque es muy pequeña. Veamos quién sufre más esta ansiedad.

# %%
mean_gender_anxiety = df.groupby('gender')['Sexual_anxiety'].mean()
mean_gender_anxiety
# Out:
# gender
# man      2.760196
# woman    2.622645
# Name: Sexual_anxiety, dtype: float64

# %%
sns.barplot(x="gender", y = "Sexual_anxiety", data=df, hue = "gender")
# Out:
# <Axes: xlabel='gender', ylabel='Sexual_anxiety'>

# %% [markdown]
# Los resultados apuntan a que los hombres sufren más ansiedad sexual que las mujeres, sin embargo, la diferencia es muy pequeña. La ansiedad sexual es definida como la tendencia a sentir tensión, incomodidad y ansiedad acerca de los aspectos sexuales de la propia vida.

# %% [markdown]
# Para probar parte de la hipótesis principal, se analiza si hay diferencias en base al género en el resto de categorías sexuales. Previamente se vuelve a comprobar el supuesto de normalidad de las variables dependientes.

# %%
columnas_a_probar = [
    'Sexual_anxiety',
    'Sexual_self-efficacy',
    'Sexual_consciousness',
    'Motivation_to_avoid_risky_sex',
    'Chance/luck_sexual_control',
    'Sexual_preoccupation',
    'Sexual_assertiveness',
    'Sexual_optimism',
    'Sexual_problem_self-blame',
    'Sexual_monitoring',
    'Sexual_motivation',
    'Sexual_problem_management',
    'Sexual_self-esteem',
    'Sexual_satisfaction',
    'Power_other_sexual_control',
    'Sexual_self-schemata',
    'Fear_of_sex',
    'Sexual_problem_prevention',
    'Sexual_depression',
    'Internal_sexual_control'
]

# Iterar sobre cada columna y realizar la prueba de normalidad
for columna in columnas_a_probar:
    ks_statistic, p_value = kstest(df[columna], 'norm')
    print(f"Columna: {columna}")
    print(f"Estadístico KS: {ks_statistic}")
    print(f"Valor P: {p_value}")
    print("\n")
# Out:
# Columna: Sexual_anxiety
# Estadístico KS: 0.8413447460685429
# Valor P: 0.0
#
#
# Columna: Sexual_self-efficacy
# Estadístico KS: 0.8961233311962864
# Valor P: 0.0
#
#
# Columna: Sexual_consciousness
# Estadístico KS: 0.9537296743241048
# Valor P: 0.0
#
#
# Columna: Motivation_to_avoid_risky_sex
# Estadístico KS: 0.958938085865651
# Valor P: 0.0
#
#
# Columna: Chance/luck_sexual_control
# Estadístico KS: 0.8413447460685429
# Valor P: 0.0
#
#
# Columna: Sexual_preoccupation
# Estadístico KS: 0.8413447460685429
# Valor P: 0.0
#
#
# Columna: Sexual_assertiveness
# Estadístico KS: 0.8413447460685429
# Valor P: 0.0
#
#
# Columna: Sexual_optimism
# Estadístico KS: 0.9007012767428288
# Valor P: 0.0
#
#
# Columna: Sexual_problem_self-blame
# Estadístico KS: 0.9089787180988518
# Valor P: 0.0
#
#
# Columna: Sexual_monitoring
# Estadístico KS: 0.8636654755345207
# Valor P: 0.0
#
#
# Columna: Sexual_motivation
# Estadístico KS: 0.8558906127257894
# Valor P: 0.0
#
#
# ...

# %%
data_to_plot = ["Sexual_anxiety", "Sexual_self-efficacy", "Sexual_consciousness", "Motivation_to_avoid_risky_sex" , "Chance/luck_sexual_control", "Sexual_preoccupation", "Sexual_assertiveness", "Sexual_optimism", "Sexual_problem_self-blame", "Sexual_monitoring", "Sexual_motivation", "Sexual_problem_management", "Sexual_self-esteem", "Sexual_satisfaction", "Power_other_sexual_control", "Sexual_self-schemata", "Fear_of_sex", "Sexual_problem_prevention", "Sexual_depression", "Internal_sexual_control"]
# Definir una función para realizar la prueba de Mann-Whitney U
def mann_whitney_test(column):
    group_man = df[df['gender'] == 'man'][column]
    group_woman = df[df['gender'] == 'woman'][column]
    mean_man = group_man.mean()
    mean_woman = group_woman.mean()

    u_statistic, p_value = mannwhitneyu(group_man, group_woman, alternative='two-sided')
    return u_statistic, p_value, mean_man, mean_woman

# Realizar la prueba de Mann-Whitney U para cada columna
for column in data_to_plot:
    u_statistic, p_value,  mean_man, mean_woman = mann_whitney_test(column)
    print(f'Columna: {column}')
    print(f'U Statistic: {u_statistic}')
    print(f'P-Value: {p_value}')
    print(f"La media de los hombres es de {mean_man} y la media de las mujeres es de {mean_woman}")
    print("\n")
# Out:
# Columna: Sexual_anxiety
# U Statistic: 20151793.0
# P-Value: 1.540385163982365e-09
# La media de los hombres es de 2.7601960045231815 y la media de las mujeres es de 2.6226452064380683
#
#
# Columna: Sexual_self-efficacy
# U Statistic: 17105276.5
# P-Value: 9.0168341816054e-21
# La media de los hombres es de 3.4057670561628344 y la media de las mujeres es de 3.5788663400979708
#
#
# Columna: Sexual_consciousness
# U Statistic: 19361368.0
# P-Value: 0.0399866238278221
# La media de los hombres es de 4.041650961176027 y la media de las mujeres es de 3.9738558432470255
#
#
# Columna: Motivation_to_avoid_risky_sex
# U Statistic: 16160270.5
# P-Value: 4.796554215193868e-46
# La media de los hombres es de 4.043874858650584 y la media de las mujeres es de 4.273030090972708
#
#
# Columna: Chance/luck_sexual_control
# U Statistic: 22270653.0
# P-Value: 5.463211997799748e-63
# La media de los hombres es de 2.5686392762909915 y la media de las mujeres es de 2.2403079076277117
#
#
# ...

# %% [markdown]
# Vamos a visualizar en un gráfico de líneas las medias de cada una de las categorías sexuales para hombres y mujeres:

# %%
# Calcular las medias de las diferentes categorías para cada género
categories = ["Sexual_anxiety", "Sexual_self-efficacy", "Sexual_consciousness", "Motivation_to_avoid_risky_sex" , "Chance/luck_sexual_control", "Sexual_preoccupation", "Sexual_assertiveness", "Sexual_optimism", "Sexual_problem_self-blame", "Sexual_monitoring", "Sexual_motivation", "Sexual_problem_management", "Sexual_self-esteem", "Sexual_satisfaction", "Power_other_sexual_control", "Sexual_self-schemata", "Fear_of_sex", "Sexual_problem_prevention", "Sexual_depression", "Internal_sexual_control"]

means_by_category = {}
for category in categories:
    means_by_category[category] = df.groupby('gender')[category].mean()

# Configurar la figura
plt.figure(figsize=(20, 10))  # Ajustar el tamaño de la figura según sea necesario
plt.xticks(rotation=90, fontsize=10)  # Rotar y ajustar el tamaño de la fuente de las etiquetas del eje x
plt.yticks(fontsize=12)  # Ajustar el tamaño de la fuente de las etiquetas del eje y

# Graficar líneas para cada categoría de datos
for category, means in means_by_category.items():
    plt.plot(means.index, means.values, marker='o', linestyle='-', label=category)

# Agregar etiquetas y leyenda
plt.xlabel('Gender', fontsize=14)
plt.legend(fontsize=12)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Conclusión**: Se observan que casi todas las categorías sexuales sufren diferencias entre hombres y mujeres de modo que:
#
# Los hombres parecen sufrir más ansiedad y depresión sexual que las mujeres, tener más conciencia sexual, sentir más control seual por azar o suerte, preocuparse más por el sexo, autoinculparse por problemas sexuales y monitorear situaciones, así como tener más motivación y mayor gestión de problemas.
#
# Las mujeres parecen tener mayor autoeficacia sexual, presentar mayor motivación para evitar riesgos sexuales, tener mayor asertividad, autoestima, optimismo, satisfacción, aunque también mayor miedo al sexo que los hombres.
#
# No parece haber diferencias signiticativas en el control por otros, autoesquemas, control sexual interno y prevención de problemas sexuales.

# %% [markdown]
# ### H2. La ansiedad sexual se vivirá en mayor o menor intensidad según el grupo de edad al que pertenezca una persona.

# %% [markdown]
# Veamos qué ocurre con la edad. ¿Hay relación entre la edad y la ansiedad sexual vivenciada? Para ello vamos a hacer la prueba no paramétrica de Kruskal-Wallis y vamos a visualizar las distribuciones de ansiedad por grupo de edad.

# %%
from scipy.stats import kruskal

# Utiliza boxplot para visualizar la distribución de ansiedad sexual por grupo de edad
sns.boxplot(x='Age Group', y='Sexual_anxiety', data=df)
plt.title('Distribución de la ansiedad sexual por grupo de edad')
plt.show()

# Aplica la prueba de Kruskal-Wallis para analizar la relación
resultado_kw = kruskal(*[grupo['Sexual_anxiety'] for nombre, grupo in df.groupby('Age Group')])

print('Estadística de prueba de Kruskal-Wallis:', resultado_kw.statistic)
print('Valor p:', resultado_kw.pvalue)
# Out:
# Estadística de prueba de Kruskal-Wallis: 62.59108071118603
# Valor p: 1.642461828632157e-13

# %% [markdown]
# Se visualiza cómo se comporta la ansiedad sexual en cada una de las edades, es decir, cómo va evolucionando la ansiedad sexual según la edad:

# %%
# Agrupar el DataFrame por la columna 'years_old' y calcular la media de 'Sexual_anxiety' para cada grupo
sexual_anxiety_mean_by_years_old = df.groupby('years_old')['Sexual_anxiety'].mean()
sexual_anxiety_mean_by_years_old

# Ordenar los valores por las etiquetas
ordered_means = sexual_anxiety_mean_by_years_old.sort_index()

# Configurar la figura
plt.figure(figsize=(20, 10))  # Ajustar el tamaño de la figura según sea necesario
plt.xticks(rotation=90, fontsize=10)  # Rotar y ajustar el tamaño de la fuente de las etiquetas del eje x
plt.yticks(fontsize=12)  # Ajustar el tamaño de la fuente de las etiquetas del eje y

# Graficar el histograma de barras
ordered_means.plot(kind='bar', width=0.8, color='skyblue', label='Frecuencia de edades')

# Graficar la línea de la media
plt.plot(ordered_means.index, ordered_means.values, marker='o', linestyle='-', color='red', label='Media de sexual anxiety')

# Agregar etiquetas y leyenda
plt.xlabel('Edades', fontsize=14)
plt.ylabel('Media', fontsize=14)
plt.legend(fontsize=12)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Se observa cómo evoluciona la media de ansiedad sexual por género conforme se avanza hacia un grupo de edad superior.

# %%
grouped = df.groupby(['Age Group', 'gender'])['Sexual_anxiety'].mean().unstack()
# Definir el orden de las categorías de edad
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

grouped
# Out:
# gender            man     woman
# Age Group
# Adolescence  2.856566  2.737660
# Adulthood    2.648722  2.451709
# Elderly      2.542857  2.162500
# Youth        2.806180  2.635736

# %%
# Reordenar el DataFrame grouped según el orden de las categorías de edad
grouped = grouped.reindex(age_group_order)

# Graficar
plt.figure(figsize=(10, 6))

grouped['man'].plot(label='men')
grouped['woman'].plot(label='women')

# Establecer el orden de las etiquetas de edad en el eje x
plt.xticks(range(len(age_group_order)), age_group_order)

plt.title('Media de ansiedad sexual por género y edad')
plt.xlabel('Edad')
plt.ylabel('Media de ansiedad sexual')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# En vista de los resultados, concluimos que sí hay relación significativa entre la edad y la ansiedad sexual manifestada, aunque esta diferencia sea muy pequeña.

# %% [markdown]
# ### H3. La satisfación sexual se vivirá de forma diferente según el grupo de edad al que pertenezca la persona

# %% [markdown]
# Se realiza la prueba no paramétrica de Kruskal-Wallis y se observa que hay diferencias significativas intergrupales.

# %%
# Utiliza boxplot para visualizar la distribución de satisfacción sexual por grupo de edad
sns.boxplot(x='Age Group', y='Sexual_satisfaction', data=df)
plt.title('Distribución de la ansiedad sexual por grupo de edad')
plt.show()

# Aplica la prueba de Kruskal-Wallis para analizar la relación
resultado_kw = kruskal(*[grupo['Sexual_satisfaction'] for nombre, grupo in df.groupby('Age Group')])

print('Estadística de prueba de Kruskal-Wallis:', resultado_kw.statistic)
print('Valor p:', resultado_kw.pvalue)
# Out:
# Estadística de prueba de Kruskal-Wallis: 8.936528143547845
# Valor p: 0.030146791598026006

# %% [markdown]
# #### Extra:

# %% [markdown]
# Se amplía la búsqueda para analizar si hay diferencias significativas en cada uno de los aspectos que mide el MSSCQ.

# %%
# Realiza la prueba de Kruskal-Wallis para cada variable dependiente["Sexual_anxiety", "Sexual_self-efficacy", "Sexual_consciousness", "Motivation_to_avoid_risky_sex" , "Chance/luck_sexual_control", "Sexual_preoccupation", "Sexual_assertiveness", "Sexual_optimism", "Sexual_problem_self-blame", "Sexual_monitoring", "Sexual_motivation", "Sexual_problem_management", "Sexual_self-esteem", "Sexual_satisfaction", "Power_other_sexual_control", "Sexual_self-schemata", "Fear_of_sex", "Sexual_problem_prevention", "Sexual_depression", "Internal_sexual_control"]
for categories in data_to_plot:
    resultado_kw = kruskal(*[grupo[categories] for nombre, grupo in df.groupby('Age Group')])
    
    # Imprime el resultado para cada variable dependiente
    print('Variable Dependiente:', categories)
    print('Estadística de prueba de Kruskal-Wallis:', resultado_kw.statistic)
    print('Valor p:', resultado_kw.pvalue)
    print('')
# Out:
# Variable Dependiente: Sexual_anxiety
# Estadística de prueba de Kruskal-Wallis: 62.59108071118603
# Valor p: 1.642461828632157e-13
#
# Variable Dependiente: Sexual_self-efficacy
# Estadística de prueba de Kruskal-Wallis: 73.42450478410979
# Valor p: 7.883706244979813e-16
#
# Variable Dependiente: Sexual_consciousness
# Estadística de prueba de Kruskal-Wallis: 24.161774192846813
# Valor p: 2.3110734964322625e-05
#
# Variable Dependiente: Motivation_to_avoid_risky_sex
# Estadística de prueba de Kruskal-Wallis: 84.43080503907422
# Valor p: 3.4381873486744013e-18
#
# Variable Dependiente: Chance/luck_sexual_control
# Estadística de prueba de Kruskal-Wallis: 38.651441678605266
# Valor p: 2.057303629517724e-08
#
# Variable Dependiente: Sexual_preoccupation
# Estadística de prueba de Kruskal-Wallis: 33.87204751421768
# Valor p: 2.1083167653135847e-07
#
# Variable Dependiente: Sexual_assertiveness
# Estadística de prueba de Kruskal-Wallis: 98.16638956317951
# Valor p: 3.852291921703891e-21
# ...

# %% [markdown]
# Se observan diferencias significativas intergrupales según el grupo de edad de la persona, salvo con la depresión sexual, con la que parece no haber diferencia intergrupal. Vamos a verla gráficamente:

# %%
# Utiliza boxplot para visualizar la distribución de depresión sexual por grupo de edad
sns.boxplot(x='Age Group', y='Sexual_depression', data=df)
plt.title('Distribución de la depresión sexual por grupo de edad')
plt.show()

# %%
sns.scatterplot(x="Sexual_depression", y= "Sexual_anxiety", 
                size = df["Sexual_self-esteem"]/1000, 
                data = df, hue = "Age Group")
# Out:
# <Axes: xlabel='Sexual_depression', ylabel='Sexual_anxiety'>

# %% [markdown]
# Se observa que no tiene mucho sentido hacer scatterplot ya que las respuestas van de 1 a 5, y por tanto, la mancha de puntos en el gráfico no va a ser orientativa, ya que van a coincidir muchos puntos en el eje x e y. Pruebo con graficar todos los grupos de edades, teniendo el cuenta el género para observar las diferencias en la satisfacción sexual:

# %%
#Ordenar las etiquetas del eje x
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

# Crea un gráfico de barras con Seaborn
sns.catplot(
    x='Age Group', 
    y='Sexual_satisfaction', 
    hue='gender', 
    data=df, 
    kind='bar', 
    height=6, 
    aspect=2, 
    palette='pastel',  # Puedes cambiar la paleta de colores si lo deseas
    legend=True,
    ci=None, #para eliminar las líneas verticales 
    order = age_group_order
)

# Ajusta el título y las etiquetas del gráfico
plt.suptitle('Satisfaction level by age group and gender', fontsize=16)
plt.xlabel('Age Group')
plt.ylabel('Average sexual satisfaction')
plt.xticks(rotation=360)  # Rota las etiquetas del eje x si es necesario

# Muestra la leyenda
plt.legend(title='Gender')

# Muestra el gráfico
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_19220\2643939875.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(

# %% [markdown]
# Se grafica igualmente la evolución de satisfacción sexual entre hombres y mujeres a lo largo de los grupos de edad.

# %%
grouped = df.groupby(['Age Group', 'gender'])['Sexual_satisfaction'].mean().unstack()
# Definir el orden de las categorías de edad
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

grouped
# Out:
# gender            man     woman
# Age Group
# Adolescence  2.746869  2.919775
# Adulthood    2.784554  3.046035
# Elderly      2.939683  3.025000
# Youth        2.705217  3.112510

# %%
# Reordenar el DataFrame grouped según el orden de las categorías de edad
grouped = grouped.reindex(age_group_order)

# Graficar
plt.figure(figsize=(10, 6))

grouped['man'].plot(label='men')
grouped['woman'].plot(label='women')

# Establecer el orden de las etiquetas de edad en el eje x
plt.xticks(range(len(age_group_order)), age_group_order)

plt.title('Media de satisfacción por género y edad')
plt.xlabel('Edad')
plt.ylabel('Media de satisfacción')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# En la prueba U de Mann Whitney se observó que había diferencia significativa entre hombres y mujeres con respecto a la satisfacción sexual, siendo la media de satisfación de las mujeres mayor a la de los hombres. En este caso, al analizar las medias por edad y la prueba de Kruskal-Wallis, se observa que son las mujeres de todos los grupos quienes viven una mayor satisfacción, sobre todo en la juventud.

# %% [markdown]
# Observamos cómo se comporta la satisfacción sexual a lo largo de los años:

# %%
# Configurar la figura
plt.figure(figsize=(20, 10))  # Ajustar el tamaño de la figura según sea necesario
plt.xticks(rotation=90, fontsize=10)  # Rotar y ajustar el tamaño de la fuente de las etiquetas del eje x
plt.yticks(fontsize=12)  # Ajustar el tamaño de la fuente de las etiquetas del eje y

# Graficar el histograma de barras sin las barras de frecuencias
ordered_means.plot(kind='line', marker='o', linestyle='-', color='skyblue', label='Mean of sexual satisfaction')

# Graficar la línea de la media
plt.plot(ordered_means.index, ordered_means.values, marker='o', linestyle='-', color='red', label='Mean of sexual satisfaction')

# Agregar etiquetas y leyenda
plt.xlabel('Edades', fontsize=14)
plt.ylabel('Media', fontsize=14)
plt.legend(fontsize=12)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### H4. La satisfacción sexual correlacionará de forma positiva con la autoestima sexual.

# %% [markdown]
# Se hace una correlación de Pearson entre la satisfacción sexual y la autoestima sexual.

# %%
from scipy.stats import pearsonr

# Calcular el coeficiente de correlación de Pearson y el valor p entre satisfacción sexual y autoestima sexual
corr_coefficient, p_value = pearsonr(df['Sexual_satisfaction'], df['Sexual_self-esteem'])

print("Coeficiente de correlación de Pearson:", corr_coefficient)
print("Valor p de significancia:", p_value)
# Out:
# Coeficiente de correlación de Pearson: 0.7813591994553802
# Valor p de significancia: 0.0

# %% [markdown]
# Se encuentra una corelación directa positiva entre autoestima y satisfacción sexual, es decir, a mayor satisfacción, mayor autoetima.

# %% [markdown]
# Se observan todas las correlaciones ordenadas de mayor a menor que tiene la satisacción sexual con otras categorías sexuales:

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calcular la matriz de correlación
correlation_matrix = numeric_df.corr()

# Ver la correlación con la variable 'Sexual_anxiety'
target_correlation = correlation_matrix['Sexual_satisfaction'].sort_values(ascending=False)

print(target_correlation)
# Out:
# Sexual_satisfaction              1.000000
# Sexual_self-esteem               0.781359
# Sexual_self-efficacy             0.722340
# Sexual_optimism                  0.596017
# Sexual_assertiveness             0.523690
# Internal_sexual_control          0.415053
# Sexual_consciousness             0.352075
# Sexual_self-schemata             0.345448
# Sexual_problem_prevention        0.275514
# Sexual_motivation                0.264767
# Sexual_problem_management        0.259350
# Motivation_to_avoid_risky_sex    0.010142
# Sexual_preoccupation            -0.003831
# Sexual_problem_self-blame       -0.004544
# age                             -0.008579
# Sexual_monitoring               -0.054748
# Power_other_sexual_control      -0.239169
# Chance/luck_sexual_control      -0.337704
# Fear_of_sex                     -0.458227
# Sexual_anxiety                  -0.648298
# Sexual_depression               -0.768869
# Name: Sexual_satisfaction, dtype: float64

# %% [markdown]
# Se ve cómo se comporta la autoestima sexual por género y en cada grupo de edad.

# %%
grouped = df.groupby(['Age Group', 'gender'])['Sexual_self-esteem'].mean().unstack()
# Definir el orden de las categorías de edad
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

grouped
# Out:
# gender            man     woman
# Age Group
# Adolescence  3.064040  3.160041
# Adulthood    3.136513  3.385300
# Elderly      3.326984  3.212500
# Youth        3.039567  3.337586

# %%
# Reordenar el DataFrame grouped según el orden de las categorías de edad
grouped = grouped.reindex(age_group_order)

# Graficar
plt.figure(figsize=(10, 6))

grouped['man'].plot(label='men')
grouped['woman'].plot(label='women')

# Establecer el orden de las etiquetas de edad en el eje x
plt.xticks(range(len(age_group_order)), age_group_order)

plt.title('Media de autoestima sexual por género y edad')
plt.xlabel('Edad')
plt.ylabel('Media de autoestima sexual')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# A su vez, ¿con qué correlacionará la autoestima sexual?

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calcular la matriz de correlación
correlation_matrix = numeric_df.corr()

# Ver la correlación con la variable Autoestima sexual
target_correlation = correlation_matrix['Sexual_self-esteem'].sort_values(ascending=False)

print(target_correlation)
# Out:
# Sexual_self-esteem               1.000000
# Sexual_self-efficacy             0.782975
# Sexual_satisfaction              0.781359
# Sexual_assertiveness             0.655624
# Sexual_optimism                  0.633754
# Sexual_consciousness             0.521850
# Internal_sexual_control          0.476586
# Sexual_self-schemata             0.466129
# Sexual_motivation                0.400819
# Sexual_problem_management        0.354627
# Sexual_problem_prevention        0.343019
# Sexual_preoccupation             0.119327
# age                              0.025160
# Motivation_to_avoid_risky_sex    0.022387
# Sexual_problem_self-blame       -0.013566
# Sexual_monitoring               -0.025867
# Power_other_sexual_control      -0.254132
# Chance/luck_sexual_control      -0.256380
# Fear_of_sex                     -0.531168
# Sexual_depression               -0.637778
# Sexual_anxiety                  -0.643823
# Name: Sexual_self-esteem, dtype: float64

# %% [markdown]
# Observamos cómo se comporta la autoeficacia sexual.

# %%
grouped = df.groupby(['Age Group', 'gender'])['Sexual_self-efficacy'].mean().unstack()
# Definir el orden de las categorías de edad
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

grouped
# Out:
# gender            man     woman
# Age Group
# Adolescence  3.382626  3.391415
# Adulthood    3.475980  3.727402
# Elderly      3.558730  3.537500
# Youth        3.361477  3.616736

# %%
# Reordenar el DataFrame grouped según el orden de las categorías de edad
grouped = grouped.reindex(age_group_order)

# Graficar
plt.figure(figsize=(10, 6))

grouped['man'].plot(label='men')
grouped['woman'].plot(label='women')

# Establecer el orden de las etiquetas de edad en el eje x
plt.xticks(range(len(age_group_order)), age_group_order)

plt.title('Media de autoeficacia sexual por género y edad')
plt.xlabel('Edad')
plt.ylabel('Media de autoeficacia sexual')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### H5. La ansiedad sexual correlacionará positivamente con el miedo al sexo.

# %% [markdown]
# Se hace una correlación de Pearson.

# %%
# Calcular el coeficiente de correlación de Pearson y el valor p entre ansiedad sexual y supervisión sexual
corr_coefficient, p_value = pearsonr(df['Sexual_anxiety'], df['Fear_of_sex'])

print("Coeficiente de correlación de Pearson:", corr_coefficient)
print("Valor p de significancia:", p_value)
# Out:
# Coeficiente de correlación de Pearson: 0.6351832277202052
# Valor p de significancia: 0.0

# %% [markdown]
# Sí hay correlación positiva de 0.63 entre ansiedad sexual y miedo al sexo.

# %% [markdown]
# Vamos a ver cómo se comporta el miedo al sexo.

# %%
grouped = df.groupby(['Age Group', 'gender'])['Fear_of_sex'].mean().unstack()
# Definir el orden de las categorías de edad
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

grouped
# Out:
# gender            man     woman
# Age Group
# Adolescence  2.457374  2.760450
# Adulthood    2.048154  2.139007
# Elderly      2.171429  2.275000
# Youth        2.353531  2.445844

# %%
# Reordenar el DataFrame grouped según el orden de las categorías de edad
grouped = grouped.reindex(age_group_order)

# Graficar
plt.figure(figsize=(10, 6))

grouped['man'].plot(label='men')
grouped['woman'].plot(label='women')

# Establecer el orden de las etiquetas de edad en el eje x
plt.xticks(range(len(age_group_order)), age_group_order)

plt.title('Media de miedo al sexo por género y edad')
plt.xlabel('Edad')
plt.ylabel('Media de miedo al sexo sexual')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Se observan todas las correlaciones ordenadas de mayor a menor que tiene la ansiedad sexual con otras categorías sexuales:

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calcular la matriz de correlación
correlation_matrix = numeric_df.corr()

# Ver la correlación con la variable 'Sexual_anxiety'
target_correlation = correlation_matrix['Sexual_anxiety'].sort_values(ascending=False)

print(target_correlation)
# Out:
# Sexual_anxiety                   1.000000
# Sexual_depression                0.792263
# Fear_of_sex                      0.635183
# Chance/luck_sexual_control       0.375691
# Power_other_sexual_control       0.367941
# Sexual_monitoring                0.304524
# Sexual_problem_self-blame        0.130045
# Sexual_preoccupation             0.078465
# Motivation_to_avoid_risky_sex    0.043079
# age                             -0.068369
# Sexual_problem_management       -0.154377
# Sexual_problem_prevention       -0.176183
# Sexual_motivation               -0.216107
# Sexual_consciousness            -0.264976
# Internal_sexual_control         -0.288256
# Sexual_self-schemata            -0.304035
# Sexual_assertiveness            -0.523752
# Sexual_self-efficacy            -0.576950
# Sexual_optimism                 -0.615231
# Sexual_self-esteem              -0.643823
# Sexual_satisfaction             -0.648298
# Name: Sexual_anxiety, dtype: float64

# %% [markdown]
# Se grafica la correlación y las frecuencias de respuesta para la ansiedad y el miedo al sexo.

# %%
sns.set(style="white", color_codes=True)

g = sns.jointplot(x='Sexual_anxiety', y='Fear_of_sex', data=df, kind='reg', scatter=False)

g.plot_joint(sns.lineplot, color='red')

g.plot_marginals(sns.histplot, color='red', kde=True)

g.set_axis_labels('Sexual Anxiety', 'Fear of sex')
g.fig.suptitle('Relación avanzada entre ansiedad sexual y miedo al sexo')

plt.subplots_adjust(top=0.95)

plt.show()

# %% [markdown]
# Se observa gráficamente con un mapa de calor todas las correlaciones entre categorías sexuales:

# %%
# Seleccionar solo las columnas numéricas
df_numeric = df.select_dtypes(include=[np.number])

# Calcular la matriz de correlación
correlation_matrix = df_numeric.corr()

# Crear el mapa de calor
plt.figure(figsize=(25, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap de correlaciones para variables numéricas')
plt.show()

# %% [markdown]
# Se reduce el mapa de calor a una visualización con las correlaciones más altas.

# %%
# Seleccionar solo las variables que quieres correlacionar
variables_a_correlacionar = ['Sexual_anxiety', 'Sexual_depression', 'Fear_of_sex', 'Sexual_satisfaction', 'Sexual_self-esteem', 'Sexual_self-efficacy']

# Filtrar el DataFrame original para incluir solo estas variables
df_variables_seleccionadas = df[variables_a_correlacionar]

# Calcular la matriz de correlación
correlation_matrix = df_variables_seleccionadas.corr()

# Crear el mapa de calor
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# Por último, se grafica la evolución de la depresión sexual, al ser la variable que más correlaciona con la ansiedad sexual.

# %%
grouped = df.groupby(['Age Group', 'gender'])['Sexual_depression'].mean().unstack()
# Definir el orden de las categorías de edad
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

grouped
# Out:
# gender            man     woman
# Age Group
# Adolescence  2.767677  2.505979
# Adulthood    2.657467  2.483559
# Elderly      2.631746  2.612500
# Youth        2.757544  2.439602

# %%
# Reordenar el DataFrame grouped según el orden de las categorías de edad
grouped = grouped.reindex(age_group_order)

# Graficar
plt.figure(figsize=(10, 6))

grouped['man'].plot(label='men')
grouped['woman'].plot(label='women')

# Establecer el orden de las etiquetas de edad en el eje x
plt.xticks(range(len(age_group_order)), age_group_order)

plt.title('Media de depresión sexual por género y edad')
plt.xlabel('Edad')
plt.ylabel('Media de depresión sexual')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Visualizaciones

# %% [markdown]
# En el notebook de visualizaciones se pueden observar diversos gráficos como apartado extra al trabajo de EDA con el que se nutrirá la presentación del proyecto.

# %%
grouped = df.groupby(['Age Group', 'gender'])['Sexual_anxiety'].mean().unstack()
# Definir el orden de las categorías de edad
age_group_order = ['Adolescence', 'Youth', 'Adulthood', 'Elderly']

grouped
# Out:
# gender            man     woman
# Age Group
# Adolescence  2.856566  2.737660
# Adulthood    2.648722  2.451709
# Elderly      2.542857  2.162500
# Youth        2.806180  2.635736

# %%
# Reordenar el DataFrame grouped según el orden de las categorías de edad
grouped = grouped.reindex(age_group_order)

# Graficar
plt.figure(figsize=(10, 6))

grouped['man'].plot(label='men')
grouped['woman'].plot(label='women')

# Establecer el orden de las etiquetas de edad en el eje x
plt.xticks(range(len(age_group_order)), age_group_order)

plt.title('Media de ansiedad sexual por género y edad')
plt.xlabel('Edad')
plt.ylabel('Media de ansiedad sexual')
plt.legend()
plt.grid(True)
plt.show()
